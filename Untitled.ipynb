# %% [markdown]
# ## 小売・飲食向け需要予測「サキミル」　調査
# ###  ソフトバンクと日本気象協会 のコラボ
# <br>
#
# ### [課題設定]　案件ごとのカスタマイズ費用

# %% [markdown]
# ![image.png](attachment:1aab2b03-c3d6-4581-8c2d-cd245307b830.png)

# %% [markdown]
# <br>
#
# # (精度)
# ### 数百種類の飲食店や小売店に特化した特徴量を所有
# ### 気象データを日本気象協会とコラボして確保した
# #### ・高解像、多種の気象データ（1km範囲、日射、風速、降水、）
# ### 月に１回、最新データでモデルメンテ
#
#
# # (低コスト)
# ## サイエンティストが行う特徴量設計など分析前の前処理が開発の大半を占める
# ## それらを汎用化・自動化で効率的な分析を実現した

# %% [markdown]
# ![image info](https://asset.watch.impress.co.jp/img/ktw/docs/1384/660/28_o.jpg)
# <br>
#
# ![image info](https://asset.watch.impress.co.jp/img/ktw/docs/1384/660/29_o.jpg)

# %% [markdown]
# ### ------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ![image info](https://asset.watch.impress.co.jp/img/ktw/docs/1384/660/30_o.jpg)
# ![image info](https://asset.watch.impress.co.jp/img/ktw/docs/1384/660/31_o.jpg)
